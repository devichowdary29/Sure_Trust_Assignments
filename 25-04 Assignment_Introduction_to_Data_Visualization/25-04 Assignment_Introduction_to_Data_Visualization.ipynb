# %% [markdown]
# # <u> Use only those concepts which have been taught till now </u>

# %% [markdown]
# ## Use the file company_sales_data.csv

# %%
import numpy as np
import pandas as pd

from datetime import datetime

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("C:\\Users\\devic\\Documents\\PYTHON\\SURE_TRUST\\Sure_Trust_Assignments\\25-04 Assignment_Introduction_to_Data_Visualization\\company_sales_data.csv")

# %% [markdown]
# # <u>**Problem 1**</u>
#
# ### Plot the total profit across the months
#
# * X label name = Month Number
# * Y label name = Total profit

# %% [markdown]
# ### Expected output:
# ![image.png](attachment:image.png)

# %%
# Your code here



plt.plot(data['month_number'], data['total_profit'], marker='o', color='b', linestyle='-')
plt.title('Company Profit per Month')
plt.xlabel('Month Number')
plt.ylabel('Total profit')
plt.show()

# %% [markdown]
# # <b><u>Problem 2 </u></b>
#
# ### Read face cream and facewash product sales data and show it using the bar chart. The bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.

# %% [markdown]
# ### Expected output:
# ![image.png](attachment:image.png)

# %%
# Your code here

face_cream_sales = data['facecream']
face_wash_sales = data['facewash']
months = data['month_number']

# %%
bar_width = 0.4
r1 = months - bar_width / 2
r2 = months + bar_width / 2

# %%
plt.bar(r1, face_cream_sales, width=bar_width, label='Face Cream', color='skyblue')
plt.bar(r2, face_wash_sales, width=bar_width, label='Face Wash', color='orange')
plt.title('Face Cream and Face Wash Sales per Month')
plt.xlabel('Month Number')
plt.ylabel('Units Sold')
plt.xticks(months)
plt.legend()
plt.show()

# %% [markdown]
# # <b><u>Problem 3</u></b>
#
# ### Display the number of units sold per month for each product using multiline plots. (i.e. separate plotline for each product ).

# %% [markdown]
# ### Expected Output:
# ![image.png](attachment:image.png)

# %%
# Your code here
